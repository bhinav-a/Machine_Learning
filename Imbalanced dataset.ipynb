# %%
import pandas as pd 
import requests

# %%
url = "https://github.com/cs109/2014_data/blob/master/countries.csv"
s = requests.get(url).content
c = pd.read_csv(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 url = "https://github.com/cs109/2014_data/blob/master/countries.csv"
#       2 s = requests.get(url).content
# ----> 3 c = pd.read_csv(s)
#
# ...

# %%
dataset["Purchased"].value_counts()
# Out:
# Purchased
# 0    257
# 1    143
# Name: count, dtype: int64

# %%
x = dataset.iloc[:,:-1]
y = dataset["Purchased"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,random_state=42 , test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 88.75

# %%
lr.predict([[45 , 26000]]) # dataset is imbalance thats why its giving output 0 but the original value was 1
# Out:
# C:\Users\anura\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %%
 from imblearn.under_sampling import RandomUnderSampler

# %%
ru = RandomUnderSampler()

# %%
ru_x , ru_y = ru.fit_resample(x,y)

# %%
ru_y.value_counts()
# Out:
# Purchased
# 0    143
# 1    143
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(ru_x,ru_y,random_state=45, test_size=0.2)

# %%
lr2 = LogisticRegression()

# %%
lr2.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr2.score(x_test,y_test)*100
# Out:
# 86.40776699029125

# %%
lr2.predict([[45 , 26000]])
# Out:
# C:\Users\anura\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
ro = RandomOverSampler()

# %%
ro_x , ro_y = ro.fit_resample(x,y)

# %%
ro_y.value_counts()
# Out:
# Purchased
# 0    257
# 1    257
# Name: count, dtype: int64

# %%
x_train , x_test , y_train , y_test = train_test_split(ro_x,ro_y,random_state=42, test_size=0.2)

# %%
lr1 = LogisticRegression()

# %%
lr1.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr1.score(x_test,y_test)
# Out:
# 0.8640776699029126

# %%
lr1.predict([[19 , 19000]])
# Out:
# C:\Users\anura\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])
